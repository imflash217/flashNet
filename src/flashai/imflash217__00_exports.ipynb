# %%
#export
TEST = "test"

# %% [markdown]
# ## Export:

# %%
! python notebook_to_script.py imflash217__00_exports.ipynb
# Out:
# Converted imflash217__00_exports.ipynb to exp/nb_00_exports.py

# %%
# !pwd
# Out:
# /home/potter217/Desktop/Study/Projects/flashai/flashNet/src/flashai

# %%
# !ls
# Out:
# exp  imflash217__00_exports.ipynb  notebook_to_script.py  run_notebook.py

# %%
# !tree
# Out:
# .
# ├── exp
# │   └── nb_00_exports.py
# ├── imflash217__00_exports.ipynb
# ├── notebook_to_script.py
# └── run_notebook.py
#
# 1 directory, 4 files

# %%
# !bat exp/nb_00_exports.py
# Out:
# ───────┬────────────────────────────────────────────────────────────────────────
#        │ File: exp/nb_00_exports.py
# ───────┼────────────────────────────────────────────────────────────────────────
#    1   │
#    2   │ ##########################################
#    3   │ ###### This file was autogenerated. ######
#    4   │ ######### DO NOT EDIT this file. #########
#    5   │ ##########################################
#    6   │ ### file to edit: dev_nb/imflash217__00_exports.ipynb ####
#    7   │
#    8   │ TEST = "test"
# ───────┴────────────────────────────────────────────────────────────────────────

# %% [markdown]
# ## How it works
#
# ```
# Remember: Jupyter notebook is stored as a dictionary in JSON format.
#             So, we can use JSON libraray to access cells from the notebook
# ```

# %%
import json

# %%
main_dict = json.load(open("imflash217__00_exports.ipynb", "r", encoding="utf-8"))
main_dict
# Out:
# {'cells': [{'cell_type': 'code',
#    'execution_count': 25,
#    'metadata': {},
#    'outputs': [],
#    'source': ['#export\n', 'TEST = "test"']},
#   {'cell_type': 'markdown', 'metadata': {}, 'source': ['## Export:']},
#   {'cell_type': 'code',
#    'execution_count': 26,
#    'metadata': {},
#    'outputs': [{'name': 'stdout',
#      'output_type': 'stream',
#      'text': ['Converted imflash217__00_exports.ipynb to exp/nb_00_exports.py\r\n']}],
#    'source': ['! python notebook_to_script.py imflash217__00_exports.ipynb']},
#   {'cell_type': 'code',
#    'execution_count': 27,
#    'metadata': {},
#    'outputs': [{'name': 'stdout',
#      'output_type': 'stream',
#      'text': ['/home/potter217/Desktop/Study/Projects/flashai/flashNet/src/flashai\r\n']}],
#    'source': ['!pwd']},
#   {'cell_type': 'code',
#    'execution_count': 28,
#    'metadata': {},
#    'outputs': [{'name': 'stdout',
#      'output_type': 'stream',
# ...

# %%
main_dict.keys()
# Out:
# dict_keys(['cells', 'metadata', 'nbformat', 'nbformat_minor'])

# %%
main_dict["cells"]
# Out:
# [{'cell_type': 'code',
#   'execution_count': 25,
#   'metadata': {},
#   'outputs': [],
#   'source': ['#export\n', 'TEST = "test"']},
#  {'cell_type': 'markdown', 'metadata': {}, 'source': ['## Export:']},
#  {'cell_type': 'code',
#   'execution_count': 26,
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['Converted imflash217__00_exports.ipynb to exp/nb_00_exports.py\r\n']}],
#   'source': ['! python notebook_to_script.py imflash217__00_exports.ipynb']},
#  {'cell_type': 'code',
#   'execution_count': 27,
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['/home/potter217/Desktop/Study/Projects/flashai/flashNet/src/flashai\r\n']}],
#   'source': ['!pwd']},
#  {'cell_type': 'code',
#   'execution_count': 28,
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
# ...

# %%
main_dict["cells"][0]
# Out:
# {'cell_type': 'code',
#  'execution_count': 25,
#  'metadata': {},
#  'outputs': [],
#  'source': ['#export\n', 'TEST = "test"']}

# %%
x = main_dict["cells"][0]["source"]
x
# Out:
# ['#export\n', 'TEST = "test"']

# %%
"".join(x[1:])
# Out:
# 'TEST = "test"'
